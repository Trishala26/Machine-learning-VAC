# %%
import pandas as pd

# %%
import numpy as np

# %%
arr=np.array([[1,2,3],[4,5,6]])
df=pd.DataFrame(arr)

# %%
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df[1]
# Out:
# 0    2
# 1    5
# Name: 1, dtype: int64

# %%
df.columns
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
arr=np.array([[1,2,3],[4,5,6]])
df=pd.DataFrame(arr,columns=['col1','col2','col3'])

# %%
df
# Out:
#    col1  col2  col3
# 0     1     2     3
# 1     4     5     6

# %%
# Dataframes from Series
s1=pd.Series(np.random.randn(5),index=['a','b','c','d','e'])

# %%
s2=pd.Series(np.random.randn(5),index=['a','b','c','d','e'])

# %%
s2
# Out:
# a   -0.677417
# b   -0.581592
# c   -1.556907
# d   -0.178154
# e    0.416422
# dtype: float64

# %%
df=pd.concat([s1,s2])

# %%
df
# Out:
# a    0.694899
# b   -0.047739
# c   -0.132861
# d   -0.462248
# e    0.190689
# a   -0.677417
# b   -0.581592
# c   -1.556907
# d   -0.178154
# e    0.416422
# dtype: float64

# %%
df=pd.concat([s1,s2],axis=1)

# %%
df
# Out:
#           0         1
# a  0.694899 -0.677417
# b -0.047739 -0.581592
# c -0.132861 -1.556907
# d -0.462248 -0.178154
# e  0.190689  0.416422

# %%
df=pd.concat([s1,s2],axis=1).reset_index()

# %%
df
# Out:
#   index         0         1
# 0     a  0.694899 -0.677417
# 1     b -0.047739 -0.581592
# 2     c -0.132861 -1.556907
# 3     d -0.462248 -0.178154
# 4     e  0.190689  0.416422

# %%
df.iloc[1][0] #pure index location
# Out:
# -0.047739425149386436

# %%
s2.to_frame() #immediate dataframe
# Out:
#           0
# a -0.677417
# b -0.581592
# c -1.556907
# d -0.178154
# e  0.416422

# %%
df
# Out:
#   index         0         1
# 0     a  0.694899 -0.677417
# 1     b -0.047739 -0.581592
# 2     c -0.132861 -1.556907
# 3     d -0.462248 -0.178154
# 4     e  0.190689  0.416422

# %%
my_df=pd.DataFrame(np.random.randn(25).reshape(5,5))

# %%
my_df
# Out:
#           0         1         2         3         4
# 0 -0.803233  1.781083  0.535303 -0.321109 -0.082805
# 1  0.987311  0.628080 -0.138591  2.227572 -0.253694
# 2 -1.057641 -1.053113 -0.417994 -1.348243 -0.168878
# 3 -0.666728 -1.080741 -1.163602  0.092335  1.143002
# 4 -0.872254  0.639693 -0.152196  1.637689 -0.319732

# %%
my_df=pd.DataFrame(np.random.randn(25).reshape((5,5)),index=['a','b','c','d','e'])

# %%
my_df
# Out:
#           0         1         2         3         4
# a -1.872981  0.804357  0.609216  0.310965  0.238003
# b -1.214363 -0.116398  0.592488 -0.281688  0.138373
# c -0.053889  0.935144  1.519340  2.647464  1.033745
# d -2.784599  0.554993 -0.549276  0.912110 -0.862653
# e  0.070839 -0.686762  0.094199  1.049739  0.664890

# %%
my_df=pd.DataFrame(np.random.randn(25).reshape((5,5)),index=['a','b','c','d','e'],columns=['c1','c2','c3','c4','c5'])

# %%
my_df
# Out:
#          c1        c2        c3        c4        c5
# a -0.056177  0.726089  0.397035 -0.508850 -0.195973
# b -0.638292 -0.031696  1.015195  0.331341  0.892915
# c -0.827235 -0.559882 -1.391764 -0.935542 -0.252542
# d -1.416141 -0.648274 -0.619617  0.295914  0.668024
# e -0.877436 -1.069989  0.160102  0.344403  0.351426

# %%
my_df.drop('b')
# Out:
#          c1        c2        c3        c4        c5
# a -0.056177  0.726089  0.397035 -0.508850 -0.195973
# c -0.827235 -0.559882 -1.391764 -0.935542 -0.252542
# d -1.416141 -0.648274 -0.619617  0.295914  0.668024
# e -0.877436 -1.069989  0.160102  0.344403  0.351426

# %%
my_df.drop('c2',axis=1)
# Out:
#          c1        c3        c4        c5
# a -0.056177  0.397035 -0.508850 -0.195973
# b -0.638292  1.015195  0.331341  0.892915
# c -0.827235 -1.391764 -0.935542 -0.252542
# d -1.416141 -0.619617  0.295914  0.668024
# e -0.877436  0.160102  0.344403  0.351426

# %%
my_df.drop('c2',axis=1,inplace=True)

# %%
my_df
# Out:
#          c1        c3        c4        c5
# a -0.056177  0.397035 -0.508850 -0.195973
# b -0.638292  1.015195  0.331341  0.892915
# c -0.827235 -1.391764 -0.935542 -0.252542
# d -1.416141 -0.619617  0.295914  0.668024
# e -0.877436  0.160102  0.344403  0.351426

# %%
my_df.describe()
# Out:
#              c1        c3        c4        c5
# count  5.000000  5.000000  5.000000  5.000000
# mean  -0.763056 -0.087810 -0.094547  0.292770
# std    0.489634  0.934916  0.592755  0.510065
# min   -1.416141 -1.391764 -0.935542 -0.252542
# 25%   -0.877436 -0.619617 -0.508850 -0.195973
# 50%   -0.827235  0.160102  0.295914  0.351426
# 75%   -0.638292  0.397035  0.331341  0.668024
# max   -0.056177  1.015195  0.344403  0.892915

# %%
my_df.transpose().describe()
# Out:
#               a         b         c         d         e
# count  4.000000  4.000000  4.000000  4.000000  4.000000
# mean  -0.090991  0.400290 -0.851771 -0.267955 -0.005377
# std    0.376390  0.753701  0.468433  0.937372  0.588083
# min   -0.508850 -0.638292 -1.391764 -1.416141 -0.877436
# 25%   -0.274192  0.088933 -1.049597 -0.818748 -0.099283
# 50%   -0.126075  0.612128 -0.881388 -0.161852  0.252252
# 75%    0.057126  0.923485 -0.683562  0.388941  0.346159
# max    0.397035  1.015195 -0.252542  0.668024  0.351426

# %%
my_df.sum()
# Out:
# c1   -3.815281
# c3   -0.439050
# c4   -0.472734
# c5    1.463849
# dtype: float64

# %%
my_df.cumsum()
# Out:
#          c1        c3        c4        c5
# a -0.056177  0.397035 -0.508850 -0.195973
# b -0.694469  1.412230 -0.177509  0.696942
# c -1.521704  0.020465 -1.113050  0.444400
# d -2.937845 -0.599152 -0.817137  1.112424
# e -3.815281 -0.439050 -0.472734  1.463849

# %%
my_df.cumsum(axis=0)
# Out:
#          c1        c3        c4        c5
# a -0.056177  0.397035 -0.508850 -0.195973
# b -0.694469  1.412230 -0.177509  0.696942
# c -1.521704  0.020465 -1.113050  0.444400
# d -2.937845 -0.599152 -0.817137  1.112424
# e -3.815281 -0.439050 -0.472734  1.463849

# %%
my_df.sum(axis=1)
# Out:
# a   -0.363965
# b    1.601159
# c   -3.407083
# d   -1.071821
# e   -0.021506
# dtype: float64

# %%
my_df.min(axis=1)
# Out:
# a   -0.508850
# b   -0.638292
# c   -1.391764
# d   -1.416141
# e   -0.877436
# dtype: float64

# %%
my_df.idxmin()
# Out:
# c1    d
# c3    c
# c4    c
# c5    c
# dtype: object

# %%
my_df.idxmin(axis=1)
# Out:
# a    c4
# b    c1
# c    c3
# d    c1
# e    c1
# dtype: object

# %%
my_df.boxplot()
# Out:
# <Axes: >
